# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“TIPE DATA DAN VARIABEL”**
#
# **Disusun Oleh :**
#
# **Muhammad Dzaky Yazid**
#
# **2611531011**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero**
#
# <br>
#
#  <img src="image/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
# Puji syukur penulis panjatkan kehadirat Tuhan Yang Maha Esa atas rahmat dan karunia-Nya, sehingga penulis dapat menyelesaikan laporan praktikum yang berjudul “Tipe Data dan Variabel” dengan baik. Laporan ini disusun sebagai bentuk dokumentasi kegiatan praktikum pada mata kuliah Praktikum Algoritma Pemrograman.
#
# Praktikum ini membahas konsep dasar tipe data dan variabel dalam bahasa pemrograman Python, seperti integer, float, complex, string, boolean, konstanta, serta penggunaan input. Selain itu, praktikum ini juga membahas penggunaan variabel untuk menyimpan dan mengolah nilai dalam suatu program.
#
# Melalui praktikum ini, penulis diharapkan dapat memahami fungsi dan penggunaan berbagai tipe data serta variabel dalam Python, sekaligus mampu menerapkannya dalam pembuatan program sederhana. Pemahaman tersebut menjadi salah satu dasar penting untuk mempelajari konsep pemrograman yang lebih lanjut.
#
# Penulis menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan untuk memperbaiki laporan ini di masa mendatang. Penulis berharap laporan ini dapat memberikan manfaat dan menambah pemahaman pembaca mengenai dasar pemrograman Python.
#
# <div align="right" style="margin-left:-30px;">
# Padang, 2026
# <br>
# <br>
# <br>
# <br>
# <br>
# Muhammad Dzaky Yazid
# <br>
# 2611531021
# </div>

# %% [markdown]
# ---
# <h1 align="center">BAB I<br>PENDAHULUAN</h1>
#
# ## 1.1 Latar Belakang
#
# Perkembangan teknologi yang semakin pesat membuat kemampuan pemrograman menjadi salah satu keterampilan dasar yang penting dalam bidang Informatika. Pemrograman memungkinkan seseorang untuk memberikan instruksi kepada komputer sehingga dapat melakukan berbagai proses sesuai dengan kebutuhan. Oleh karena itu, pemahaman terhadap konsep-konsep dasar pemrograman perlu dikuasai sejak awal sebagai bekal untuk mempelajari materi pemrograman yang lebih lanjut.
#
# Python merupakan salah satu bahasa pemrograman yang banyak digunakan karena memiliki sintaks yang sederhana dan mudah dipahami oleh pemula. Dalam mempelajari Python, terdapat beberapa konsep dasar yang perlu dipahami, salah satunya adalah tipe data dan variabel. Tipe data berfungsi untuk menentukan jenis nilai yang digunakan dalam program, sedangkan variabel digunakan sebagai tempat untuk menyimpan nilai yang dapat digunakan dalam proses pengolahan data.
#
# Melalui praktikum Tipe Data dan Variabel, mahasiswa dapat mempelajari secara langsung berbagai tipe data yang terdapat dalam Python, seperti integer, float, complex, string, dan boolean, serta memahami penggunaan konstanta dan input. Pemahaman terhadap konsep tersebut diharapkan dapat membantu mahasiswa dalam membuat program sederhana sekaligus menjadi dasar untuk mempelajari struktur dan logika pemrograman pada tahap berikutnya.
#
# ## 1.2 Tujuan
# 1. Memahami konsep dasar tipe data dalam bahasa pemrograman Python.
# 2. Memahami konsep dan penggunaan variabel dalam Python.
# 3. Mampu membedakan berbagai jenis tipe data seperti int, float, komplek, string, boolean, konstanta serta penggunaan input.
# 4. Mampu menggunakan tipe data dan variabel dalam pembuatan program sederhana.
# 5. Mampu menerapkan tipe data dan variabel untuk mengolah data dalam program Python.
# ## 1.3 Manfaat
# 1. Memberikan pengalaman kepada mahasiswa dalam menggunakan tipe data dan variabel pada Python.
# 2. Meningkatkan pemahaman mahasiswa mengenai berbagai jenis tipe data.
# 3. Membantu mahasiswa memahami cara menyimpan dan mengolah data menggunakan variabel.
# 4. Melatih mahasiswa dalam menerapkan tipe data dan variabel pada program sederhana.
# 5. Menjadi dasar bagi mahasiswa untuk mempelajari konsep pemrograman Python yang lebih lanjut.

# %% [markdown]
# ---
# <h1 align="center">BAB II<br>PEMBAHASAN</h1>
#
# ## 2.1 Dasar Teori
#
# Praktikum Pengenalan Python, VS Code, dan Koneksi ke GitHub membahas dasar penggunaan bahasa pemrograman Python, Visual Studio Code sebagai code editor, serta GitHub sebagai media penyimpanan dan pengelolaan kode program.
#
# Praktikum Tipe Data dan Variabel membahas konsep dasar dalam bahasa pemrograman Python yang digunakan untuk menyimpan dan mengolah data. Tipe data menentukan jenis nilai yang digunakan dalam program, sedangkan variabel digunakan untuk menyimpan atau mereferensikan nilai tersebut.
#
# 1. Integer (int)<br>
# Integer merupakan tipe data yang digunakan untuk menyimpan bilangan bulat, seperti 10, 25, dan -5.
# 2. Float (float)<br>
# Float digunakan untuk menyimpan bilangan yang memiliki nilai desimal, seperti 3.14, 10.5, dan 0.75.
# 3. Complex (complex)<br>
# Complex merupakan tipe data yang digunakan untuk menyimpan bilangan kompleks yang memiliki bagian real dan imajiner. Contohnya adalah 3+2j.
# 4. String (str)<br>
# String merupakan tipe data yang digunakan untuk menyimpan teks atau kumpulan karakter. String ditulis menggunakan tanda kutip, contohnya "Python" dan "Informatika".
# 5. Boolean (bool)<br>
# Boolean merupakan tipe data yang memiliki dua nilai, yaitu True dan False. Tipe data ini biasanya digunakan untuk menyatakan kondisi benar atau salah.
# 6. Konstanta<br>
# Konstanta merupakan nilai yang secara konsep tidak dimaksudkan untuk diubah selama program berjalan. Python tidak memiliki sintaks khusus untuk membuat konstanta, tetapi penamaan dengan huruf kapital dapat digunakan sebagai tanda bahwa suatu variabel dianggap sebagai konstanta, contohnya PI = 3.14.
# 7. Variabel<br>
# Variabel digunakan sebagai tempat untuk menyimpan atau mereferensikan suatu nilai. Dalam Python, variabel dapat dibuat dengan memberikan nilai menggunakan operator =, misalnya nama = "Adib" atau umur = 18.
# 8. Input dan Output<br>
# Python menyediakan fungsi input() untuk menerima data dari pengguna dan print() untuk menampilkan data ke layar. Data dari input() secara default bertipe str, sehingga perlu dilakukan konversi apabila data tersebut akan digunakan sebagai bilangan.
# <br>
# <br>
# Dengan memahami tipe data dan variabel, mahasiswa dapat menentukan jenis data yang sesuai serta menggunakannya dalam proses pengolahan data pada program Python.
#
# ## 2.2 Kode Program
#
# ### 2.2.1 Program Numeric_2611531011

# %%
#create a variable with integer value
a_1011=100
print("the type of variable having value", a_1011, "is", type(a_1011))

#create a variable with float value
b_1011=10.2345
print("the type of variable having value", b_1011, "is", type(b_1011))

#create a variable with complex value
c_1011=100+3j
print("the type of variable having value", c_1011, "is", type(c_1011))
# Out:
# The type of variable having value 100 is <class 'int'>
# The type of variable having value 10.2345 is <class 'float'>
# The type of variable having value (100+3j) is <class 'complex'>

# %% [markdown]
# Penjelasan:
#
# 1. Deklarasi a_1011 dengan nilai 100 sebagai integer.
# 2. Cetak ("The type of variable having value",a_1011,"is",type(a_1011)) dengan type() digunakan untuk mengetahui tipe variabel dari a_1011.
# 3. Deklarasi b_1011 dengan nilai 10.2345 sebagai float.
# 4. Cetak ("The type of variable having value",b_1011,"is",type(b_1011)) dengan type() digunakan untuk mengetahui tipe variabel dari b_1011.
# 5. Deklarasi c_1011 dengan nilai (100 + 3j) sebagai komplek.
# 6. Cetak ("The type of variable having value",c_1011,"is",type(c_1011)) dengan type() digunakan untuk mengetahui tipe variabel dari c_1011
#
#
# ### 2.2.2 Program String_2611531011

# %%
# Buat file dengan nama string String_2611531011.py
# nama variabel ditambah 4 digit terakhir contoh: nama_1011
# ganti programnya dan data masing2
nama_1011="Yazid"
jenis_kelamin_1011="L"
alamat_1011="""
Komplek palm griya indah II
kecamatan kuranji
kota padang
"""
agama_1011="islam"
print("nama saya adalah: ", nama_1011)
print("jenis kelamin saya adalah: ", jenis_kelamin_1011)
print("alamat saya adalah: ", alamat_1011)
print("agama saya adalah: ", agama_1011)
# Out:
# nama saya adalah:  Yazid
# jenis kelamin saya adalah:  L
# alamat saya adalah:
# Komplek palm griya indah II
# kecamatan kuranji
# kota padang
#
# agama saya adalah:  islam

# %% [markdown]
# Penjelasan:
#
# 1. Deklarasi nama_1011 = "Yazid" sebagai string
# 2. Deklarasi jenis_kelamin_1011 = 'L' sebagai string
# 3. Deklarasi alamat_1011 = """Komplek palm griya indah II, kecamatan kuranji, kota padang""" sebagai string
# 4. Deklarasi agama_1011 = "Islam" sebagai string
# 5. Cetak ("Nama saya adalah: ", nama_1011)
# 6. Cetak ("Jenis kelamin saya adalah: ", jenis_kelamin_1011)
# 7. Cetak ("Alamat saya adalah: ", alamat_1011)
# 8. Cetak ("Agama saya adalah: ", agama_1011)
# ### 2.2.3 Program Boolean_2611531011

# %%
# Buat file dengan nama Boolean_2611531011
# Nama variabel ditambah 4 digit nim terakhir contoh: nilai_1234
# Deklarasi variabel dengan tipe data Boolean
is_lulus_1011=True
is_cumlaude_1011=True

# menggunakan boolean
nilai_1011=85
batas_lulus_1011=75

#m menentukan nilai boolean dari kondisi
status_kelulusan_1011=nilai_1011>=batas_lulus_1011

print("=== check kelulusan ===")
print("nilai :" , nilai_1011)
print("apakah lulus? :", status_kelulusan_1011)
if is_lulus_1011 and is_cumlaude_1011:
    print("selamat anda lulus dengan predikat cum laude")
# Out:
# === check kelulusan ===
# nilai : 85
# apakah lulus? : True
# selamat anda lulus dengan predikat cum laude

# %% [markdown]
# Penjelasan:
#
# 1. Deklarasi is_lulus_1011 = True sebagai boolean
# 2. Deklarasi is_cumlaude_1011 = True sebagai boolean
# 3. Deklarasi nilai_1011 = 85 sebagai integer
# 5. Deklarasi batas_lulus_1011 = 75 sebagai integer
# 6. Deklarasi status_kelulusan_1011 = nilai_1021 >= batas_lulus_1011 sebagai boolean
# 7. Cetak ("=== Check Kelulusan ===")
# 8. Cetak ("Nilai: ",nilai_1011)
# 9. Cetak ("Apakah lulus?: ",status_kelulusan_1011)
# 10. Jika is_lulus_1011 dan is_cumlaude_1011 bernilai benar cetak ("Selamat, Anda lulus dengan predikat Cum Laude!")
#
# ### 2.2.4 Program Input_2611531011

# %%
# Buat file dengan nama Input_2611531011.py
# Buat Program untuk menghitung luas persegi panjang
# Nama variabel ditambah 4 digit nim terakhir contoh: nama_1011
# Program ini menggunakan fungsi input() untuk meminta pengguna
# memasukan nilai panjang dan lebar persegi panjang
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
panjang_1011 = input("Masukkan nilai panjang: ")
lebar_1011 = input("Masukkan nilai lebar: ")
luas_1011 = int(panjang_1011) * int(lebar_1011)
print("Luas = ",luas_1011)
# Out:
# Luas =  231

# %% [markdown]
# Penjelasan:
#
# 1. Input nilai panjang_1011
# 2. Input nilai lebar_1011
# 3. Nilai luas_1021 = int(panjang_1011) * int(lebar_1011)
# 4. Cetak ("Luas = ",luas_1011)
#
# ### 2.2.5 Program Konstanta_2611531011

# %%
# Buat file dengan nama Konstanta_2611531011
# Program ini menggunakan konstanta untuk menghitun luas lingkaran
# nama variabel ditambah 4 digit nim terakhir contoh: jari_1011

from typing import Final
pi: Final = 3.14
print("pi: %f" % (pi))
jari_1011=float(input("masukkan nilai jari-jari: "))
luas_1011=pi * jari_1011 * jari_1011
print("luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_1011, luas_1011))
# Out:
# pi: 3.140000
# luas lingkaran dengan jari-jari 10.00 adalah 314.00

# %% [markdown]
# Penjelasan:
#
# 1. Pemanggilan Final dari library typing from typing import Final
# 2. Deklarasi PI: Final = 3.14 sebagai konstanta
# 3. Cetak ("Pi: %f" % (PI))
# 4. Nilai jari_1011 = float(input("Masukkan nilai jari-jari: "))
# 5. Nilai luas_1011 = PI * jari_1011
# 6. Cetak ("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_1011,luas_1011))

# %% [markdown]
# ---
# <h1 align="center">BAB III<br>KESIMPULAN</h1>
#
# Berdasarkan praktikum yang telah dilaksanakan, dapat disimpulkan bahwa pemahaman mengenai tipe data dan variabel merupakan bagian penting dalam mempelajari dasar pemrograman Python. Berbagai tipe data memiliki fungsi yang berbeda dalam menentukan jenis nilai yang digunakan, sementara variabel berperan dalam menyimpan dan mengelola nilai tersebut selama program dijalankan.
#
# Melalui praktikum ini, mahasiswa dapat memahami penggunaan tipe data seperti int, float, complex, string, dan boolean, serta penggunaan konstanta dan input dalam program. Pemahaman tersebut dapat membantu mahasiswa dalam membuat program sederhana dengan lebih terstruktur dan menjadi bekal untuk mempelajari materi pemrograman Python yang lebih kompleks.

# %% [markdown]
# ---
# <h1 align="center">DAFTAR PUSTAKA</h1>
#
# 1. Python Software Foundation. (2026). Built-in Types — Python 3.14.7 documentation.
# https://docs.python.org/3/library/stdtypes.html
#
# 2. Python Software Foundation. (2026). The Python Language Reference — Python 3.14.7 documentation.
# https://docs.python.org/3/reference/
#
# 3. Python Software Foundation. (2026). Built-in Functions — Python 3.14.7 documentation.
# https://docs.python.org/3/library/functions.html
#
# 4. Python Software Foundation. (2026). Tipe Data — Dokumentasi Python 3.14.7.
# https://docs.python.org/id/3/library/datatypes.html
